# %% [markdown]
# <a href="https://colab.research.google.com/github/roklp/MLP34/blob/main/%EB%A9%80%EC%BA%A0_pandas_test_240105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## (1) 라이브러리 불러오기
# - numpy, pandas, seaborn 라이브러리를 불러온다.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## (2) 데이터 불러오기
# - tips 데이터를 불러와서 tips라고 저장한다.

# %%
# sns.get_
tips = sns.load_dataset("tips")

# %% [markdown]
# ## (3) 특정 행 추출
# - loc을 사용하여 tips 데이터셋의 처음 3행의 데이터를 추출하세요.

# %%
# tips.head(3)
# loc 의 l은 로케이션을 의미 Label 기반
# iloc 의 i는 정수를 의미 Index 기반
tips.loc[0:2, :]


#tips.iloc[0:3, :]    iloc 사용시 조건식 사용이 불가능해서 그냥 loc 만 공부하도록 하자
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ## (4) 특정 열 추출
# - loc을 사용하여 모든 레코드에 대한 'total_bill'과 'tip' 열을 추출하세요.

# %%
tips.loc[:, ['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# ## (5) 특정 행과 열의 조합
# - loc을 사용하여 처음 5행에 대해 'total_bill', 'tip', 'day' 열을 추출하세요.

# %%
tips.loc[:4, ['total_bill', 'tip', 'day']]
# Out:
#    total_bill   tip  day
# 0       16.99  1.01  Sun
# 1       10.34  1.66  Sun
# 2       21.01  3.50  Sun
# 3       23.68  3.31  Sun
# 4       24.59  3.61  Sun

# %% [markdown]
# ## (6) 조건에 따른 행 추출
# - 'day'가 'Sunday'인 모든 행을 추출하고 'total_bill'과 'tip' 열만 표시하세요.

# %%
tips.loc[tips['day'] == 'Sun', ['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 186       20.90  3.50
# 187       30.46  2.00
# 188       18.15  3.50
# 189       23.10  4.00
# 190       15.69  1.50
#
# [76 rows x 2 columns]

# %% [markdown]
# ## (7) 다중 조건에 따른 행 추출
# - loc을 사용하여 'time'이 'Dinner'이고 'tip'이 5달러 이상인 모든 행을 선택하고 'total_bill', 'sex', 'smoker' 열만 표시하세요.

# %%
result = tips.loc[(tips['time'] == 'Dinner') & (tips['tip'] >= 5), ['total_bill', 'sex', 'smoker', 'tip']]

# %%
result.reset_index(drop=True)
result.head(5)
# Out:
#     total_bill     sex smoker   tip
# 11       35.26  Female     No  5.00
# 23       39.42    Male     No  7.58
# 39       31.27    Male     No  5.00
# 44       30.40    Male     No  5.60
# 46       22.23    Male     No  5.00
